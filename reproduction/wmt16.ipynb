# %% [markdown]
# # WMT16
#
# * Segment level (pearson) correlation to human scores

# %%
# install dependencies

# !pip -q install datasets
# !pip -q install bert_score
# !pip -q install git+https://github.com/google-research/bleurt.git
# !pip -q install unbabel-comet
# !pip -q install transformers
# !pip -q install POT
# Out:
#      |████████████████████████████████| 365 kB 37.0 MB/s
#      |████████████████████████████████| 141 kB 72.2 MB/s
#      |████████████████████████████████| 212 kB 68.7 MB/s
#      |████████████████████████████████| 115 kB 73.5 MB/s
#      |████████████████████████████████| 101 kB 12.1 MB/s
#      |████████████████████████████████| 596 kB 68.6 MB/s
#      |████████████████████████████████| 127 kB 62.7 MB/s
#      |████████████████████████████████| 60 kB 1.5 MB/s
#      |████████████████████████████████| 4.7 MB 37.9 MB/s
#      |████████████████████████████████| 6.6 MB 16.0 MB/s
#      |████████████████████████████████| 352 kB 11.8 MB/s
#      |████████████████████████████████| 1.3 MB 60.4 MB/s
#   Building wheel for BLEURT (setup.py) ... done
#      |████████████████████████████████| 64 kB 2.7 MB/s
#      |████████████████████████████████| 116 kB 72.9 MB/s
#      |████████████████████████████████| 409 kB 62.0 MB/s
#      |████████████████████████████████| 585 kB 47.2 MB/s
#      |████████████████████████████████| 101 kB 10.4 MB/s
#      |████████████████████████████████| 9.5 MB 52.4 MB/s
#      |████████████████████████████████| 664 kB 35.1 MB/s

# %%
# !git clone https://github.com/drehero/geneval
# Out:
# Cloning into 'geneval'...
# remote: Enumerating objects: 582, done.
# remote: Counting objects: 100% (232/232), done.
# remote: Compressing objects: 100% (159/159), done.
# remote: Total 582 (delta 102), reused 187 (delta 63), pack-reused 350
# Receiving objects: 100% (582/582), 53.29 MiB | 11.59 MiB/s, done.
# Resolving deltas: 100% (246/246), done.
# Checking out files: 100% (192/192), done.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pathlib

import datasets
import numpy as np
import pandas as pd
from scipy.stats import pearsonr

from geneval.geneval.data.wmt import WMT16

# %%
# import metric config
from geneval.reproduction.configs import baryscore_config as config

# %%
config.compute_args["batch_size"] = 64

# %%
out_path = pathlib.Path(f"/content/drive/MyDrive/results/wmt16/")
lang_pairs = ["cs-en", "de-en", "fi-en", "ru-en"]

# %%
scorer = datasets.load_metric(config.metric_path, **config.load_args)

# %%
for lang_pair in lang_pairs:
    # load data
    wmt = WMT16(lang_pair)

    # compute score
    args = config.compute_args.copy()
    if config.uses_reference:
        args["references"] = wmt.references
    if config.uses_source:
        args["sources"] = wmt.sources
    
    scores = scorer.compute(
        predictions=wmt.translations,
        **args
    )

    # save
    df = pd.DataFrame({
        "translation": wmt.translations,
        "reference": wmt.references,
        "source": wmt.sources,
        "human_score": wmt.scores,
        "metric_score": scores[config.score_name] if config.score_name is not None else scores
    })
    if "model_type" in args.keys():
        fn = f"{lang_pair}-{args['model_type'].split('/')[-1]}.csv"
    elif "config_name" in config.load_args.keys():
        fn = f"{lang_pair}-{config.load_args['config_name'].split('/')[-1]}.csv"
    else:
        fn = f"{lang_pair}.csv"
    df.to_csv(out_path / config.metric_name / fn, index=False)
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-8d1f49ca0353> in <module>
#      12     scores = scorer.compute(
#      13         predictions=wmt.translations,
# ---> 14         **args
#      15     )
#      16
#
# /usr/local/lib/python3.7/dist-packages/datasets/metric.py in compute(self, predictions, references, **kwargs)
#     436             inputs = {input_name: self.data[input_name] for input_name in self.features}
#     437             with temp_seed(self.seed):
# --> 438                 output = self._compute(**inputs, **compute_kwargs)
#     439
#     440             if self.buf_writer is not None:
#
# ~/.cache/huggingface/modules/datasets_modules/metrics/baryscore/ddc8f26c7c0fb755fa844f5485c75f33b9db8be798f90ffe941a89a1c83a87a1/baryscore.py in _compute(self, predictions, references, model_type, batch_size, last_layers, use_idfs, sinkhorn_ref)
#     319         """Returns the scores"""
#     320         scorer = BaryScoreMetric(
# --> 321             model_name=model_type, last_layers=last_layers, use_idfs=use_idfs, sinkhorn_ref=sinkhorn_ref
#     322         )
#     323         scorer.prepare_idfs(hyps=predictions, refs=references)
#
# ~/.cache/huggingface/modules/datasets_modules/metrics/baryscore/ddc8f26c7c0fb755fa844f5485c75f33b9db8be798f90ffe941a89a1c83a87a1/baryscore.py in __init__(self, model_name, last_layers, use_idfs, sinkhorn_ref)
#      68
#      69         self.model_name = model_name
# ---> 70         self.load_tokenizer_and_model()
#      71         n = self.model.config.num_hidden_layers + 1
#      72         assert n - last_layers > 0
#
# ~/.cache/huggingface/modules/datasets_modules/metrics/baryscore/ddc8f26c7c0fb755fa844f5485c75f33b9db8be798f90ffe941a89a1c83a87a1/baryscore.py in load_tokenizer_and_model(self)
#     108         Loading and initializing the chosen model and tokenizer
#     109         """
# --> 110         tokenizer = AutoTokenizer.from_pretrained('{}'.format(self.model_name))
#     111         model = AutoModelForMaskedLM.from_pretrained('{}'.format(self.model_name))
#     112         model.config.output_hidden_states = True
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     607             tokenizer_class_py, tokenizer_class_fast = TOKENIZER_MAPPING[type(config)]
#     608             if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# --> 609                 return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     610             else:
#     611                 if tokenizer_class_py is not None:
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, *init_inputs, **kwargs)
#    1750                         local_files_only=local_files_only,
#    1751                         use_auth_token=use_auth_token,
# -> 1752                         user_agent=user_agent,
#    1753                     )
#    1754
#
# /usr/local/lib/python3.7/dist-packages/transformers/utils/hub.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#     290             user_agent=user_agent,
#     291             use_auth_token=use_auth_token,
# --> 292             local_files_only=local_files_only,
#     293         )
#     294     elif os.path.exists(url_or_filename):
#
# /usr/local/lib/python3.7/dist-packages/transformers/utils/hub.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#     499     if not local_files_only:
#     500         try:
# --> 501             r = requests.head(url, headers=headers, allow_redirects=False, proxies=proxies, timeout=etag_timeout)
#     502             _raise_for_status(r)
#     503             etag = r.headers.get("X-Linked-Etag") or r.headers.get("ETag")
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in head(url, **kwargs)
#     102
#     103     kwargs.setdefault('allow_redirects', False)
# --> 104     return request('head', url, **kwargs)
#     105
#     106
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379         # Trigger any extra validation we need to do.
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#     383             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     976         # Force connect early to allow us to validate the connection.
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#     980         if not conn.is_verified:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connection.py in connect(self)
#     369             ca_cert_data=self.ca_cert_data,
#     370             server_hostname=server_hostname,
# --> 371             ssl_context=context,
#     372         )
#     373
#
# /usr/local/lib/python3.7/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     384     ) or IS_SECURETRANSPORT:
#     385         if HAS_SNI and server_hostname is not None:
# --> 386             return context.wrap_socket(sock, server_hostname=server_hostname)
#     387
#     388         warnings.warn(
#
# /usr/lib/python3.7/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     421             server_hostname=server_hostname,
#     422             context=self,
# --> 423             session=session
#     424         )
#     425
#
# /usr/lib/python3.7/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     868                         # non-blocking
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#     872                 self.close()
#
# /usr/lib/python3.7/ssl.py in do_handshake(self, block)
#    1137             if timeout == 0.0 and block:
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#    1141             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
# load scores and compute pearson correlation
results = {}
for lang_pair in lang_pairs:
    if "model_type" in config.compute_args.keys():
        fn = f"{lang_pair}-{config.compute_args['model_type'].split('/')[-1]}.csv"
    elif "config_name" in config.load_args.keys():
        fn = f"{lang_pair}-{config.load_args['config_name'].split('/')[-1]}.csv"
    else:
        fn = f"{lang_pair}.csv"
    df = pd.read_csv(out_path / config.metric_name / fn)
    corr = pearsonr(df["metric_score"], df["human_score"])[0]
    results[lang_pair] = corr

# %%
results
# Out:
# {'cs-en': -0.7513220224201244,
#  'de-en': -0.7299728767472832,
#  'fi-en': -0.7680262081558806,
#  'ru-en': -0.7302746298921875}
